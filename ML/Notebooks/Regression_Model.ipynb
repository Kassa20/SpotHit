# %% [markdown]
#  Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import IPython.display as ipd
import gdown

# for the ML
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from IPython import display
import ipywidgets as widgets

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Load existing spotify data

# %%
data_url = 'https://drive.google.com/uc?id=1MIkOcP2JY_foloYAR5-Y60YyRVbRhQMs'

data_path = './spotify_data_urls.csv'
gdown.download(data_url, data_path , True)

## Load in data
data = pd.read_csv(data_path)
basic_data = data[['Artist','Track','Year','url','Label']]

# %%
X = data[['danceability','energy','key','loudness','mode','speechiness','acousticness','instrumentalness','liveness','valence','tempo']]
y = data[['Label']]

# %%
for lr_score in range(3):
  X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

  lr = LogisticRegression()
  lr.fit(X_train,y_train)

  lr_score = lr.score(X_test,y_test)
  print ("LR Score:", lr_score)
# Out:
# LR Score: 0.6927297668038409
# LR Score: 0.6941015089163237
# LR Score: 0.7119341563786008

# %% [markdown]
# Important features

# %%
coef = lr.coef_
pd.DataFrame(list(zip(X, coef[0])), columns=['feature', 'coef'])
# Out:
#              feature      coef
# 0       danceability  3.281145
# 1             energy -1.129436
# 2                key -0.019141
# 3           loudness  0.137382
# 4               mode  0.087995
# 5        speechiness -1.565350
# 6       acousticness -1.606045
# 7   instrumentalness -3.423943
# 8           liveness -1.140124
# 9            valence -0.896453
# 10             tempo  0.002782

# %% [markdown]
# # Main

# %%
X_2 = data[['danceability','energy','key','loudness','mode','speechiness','acousticness','instrumentalness','liveness','valence','tempo']]
y_2 = data[['Label']]

X_train, X_test, y_train, y_test = train_test_split(X_2, y_2, test_size=0.2)

model = LogisticRegression()
model.fit(X_train, y_train)

accuracy = model.score(X_test, y_test)
print("accuracy: ", accuracy)
# Out:
# accuracy:  0.6886145404663924

# %% [markdown]
# # New Data

# %%
music_data_url = 'https://drive.google.com/uc?id=1Q4UAv4FPPOlhmFWHkn4Y83dG6M51xnoM'
music_data_path = './data_with_most_lyrics.csv'
gdown.download(music_data_url, music_data_path, True)
# Out:
# './data_with_most_lyrics.csv'

# %%
music_data = pd.read_csv(music_data_path)
music_data = music_data.drop(columns=['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.2'])
music_data['lyrics'] = music_data['lyrics'].str.replace('\n', ' ')
available_songs = music_data["track_name"] 
available_songs = available_songs.tolist()
#

# %%
music_data
# Out:
#                          artist_name                           track_name  \
# 0                        Miley Cyrus                  Party In The U.S.A.
# 1                    Waylon Jennings  The Year 2003 Minus 25 - Remastered
# 2                           Kid Cudi             Day 'N' Nite (nightmare)
# 3                             SHINee                       Ring Ding Dong
# 4                           Kid Cudi     Pursuit Of Happiness (Nightmare)
# ...                              ...                                  ...
# 12107  Musica Rilassante & Benessere         Bubbly New Years Resolutions
# 12108                             NF                                STORY
# 12109                      Roger Fly                    This Is Next Year
# 12110                    Myke Towers                            DE NOVELA
# 12111       Asian Tradition Universe                     New Year's Feast
#
#                                             album                track_id  \
# 0                           The Time Of Our Lives  5Q0Nhxo0l2bP3pNjpGJwV1
# 1                                 Waylon & Willie  0sFq478LIo9BFwf2qzMzzF
# 2                 Man On The Moon: The End Of Day  5FEXPoPnzueFJQCPRIrC3c
# 3         2009, Year Of Us - The Third Mini Album  4vLqN0bIxIQjlet2mIMBnx
# 4                 Man On The Moon: The End Of Day  5iSEsR6NKjlC9SrIJkyL3k
# ...                                           ...                     ...
# 12107              Dashing Music for 2021 - Piano  3XL5UxBSiFHSoX23znuyea
# 12108                        CLOUDS (THE MIXTAPE)  7HiIy4QaA5ud7ZuuyBysKk
# 12109                    New Year Funky Jazz 2021  2X22apMQmcOQyM4qGGN94n
# 12110                                   LYKE MIKE  7m6oknLLj0b6HnfB757DaQ
# 12111  Chinese New Year 2021: Year of the Buffalo  20Ej3JOZYSUMgIrMjS6Z16
#
#        track_popularity  year  artist_popularity  artist_followers  \
# 0                    74  2009                 89          14958283
# 1                    44  2009                 72            917987
# 2                    73  2009                 87           4787381
# 3                    59  2009                 73           2289681
# 4                    73  2009                 87           4787381
# ...                 ...   ...                ...               ...
# 12107                 1  2021                 36              8897
# 12108                72  2021                 88           5394641
# 12109                 0  2021                  0                 1
# 12110                67  2021                 96           5184385
# 12111                 0  2021                 14                57
#
#                                                   genres  danceability  ...  \
# 0                  ['dance pop', 'pop', 'post-teen pop']         0.652  ...
# 1      ['country', 'country rock', 'outlaw country', ...         0.626  ...
# 2                     ['hip hop', 'ohio hip hop', 'rap']         0.871  ...
# 3                           ['k-pop', 'k-pop boy group']         0.835  ...
# 4                     ['hip hop', 'ohio hip hop', 'rap']         0.630  ...
# ...                                                  ...           ...  ...
# 12107                                ['musica de fondo']         0.698  ...
# 12108                      ['hip hop', 'pop rap', 'rap']         0.528  ...
# 12109                                                 []         0.746  ...
# 12110                                    ['trap latino']         0.576  ...
# 12111                                                 []         0.412  ...
#
#        mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0         0       0.0420       0.00112          0.000115    0.0886   0.4700
# 1         1       0.0384       0.35500          0.000009    0.0668   0.4740
# 2         0       0.0761       0.49900          0.000004    0.1140   0.7990
# 3         1       0.0431       0.12500          0.000501    0.2220   0.8110
# 4         1       0.0414       0.48400          0.000093    0.2980   0.2660
# ...     ...          ...           ...               ...       ...      ...
# 12107     1       0.1490       0.99000          0.952000    0.1200   0.0987
# 12108     1       0.5320       0.64500          0.000000    0.6170   0.5120
# 12109     1       0.0283       0.31900          0.897000    0.1900   0.5920
# 12110     0       0.5190       0.20000          0.000003    0.0936   0.7070
# 12111     0       0.0285       0.09510          0.825000    0.4460   0.6510
#
#          tempo  duration_ms  time_signature  \
# 0       96.021       202067               4
# 1      102.166       184267               4
# 2      137.996       221267               4
# 3      124.980       233280               4
# 4      115.277       295293               4
# ...        ...          ...             ...
# 12107  101.555       121858               3
# 12108  179.835       279941               3
# 12109  104.947       211635               4
# 12110   86.411       172053               3
# 12111  147.430       216904               4
#
#                                                   lyrics
# 0      I hopped off the plane at L.A.X. with a dream ...
# 1                                                    NaN
# 2      [Kid Cudi:] Day and night (what, what) I toss ...
# 3      [Jonghyun] Baby Negae banhae beorin naegae wae...
# 4      Crush a bit, little bit Roll it up, take a hit...
# ...                                                  ...
# 12107                                                NaN
# 12108  Woke up in a bad place Should probably get up ...
# 12109                                                NaN
# 12110                                                NaN
# 12111                                                NaN
#
# [12112 rows x 23 columns]

# %%
from sklearn.metrics import accuracy_score

X_new = music_data[['danceability','energy','key','loudness','mode','speechiness','acousticness','instrumentalness','liveness','valence','tempo']]
music_data['hit_prediction'] = model.predict(X_new)

# %%
music_data.head(5)
# Out:
#        artist_name                           track_name  \
# 0      Miley Cyrus                  Party In The U.S.A.
# 1  Waylon Jennings  The Year 2003 Minus 25 - Remastered
# 2         Kid Cudi             Day 'N' Nite (nightmare)
# 3           SHINee                       Ring Ding Dong
# 4         Kid Cudi     Pursuit Of Happiness (Nightmare)
#
#                                      album                track_id  \
# 0                    The Time Of Our Lives  5Q0Nhxo0l2bP3pNjpGJwV1
# 1                          Waylon & Willie  0sFq478LIo9BFwf2qzMzzF
# 2          Man On The Moon: The End Of Day  5FEXPoPnzueFJQCPRIrC3c
# 3  2009, Year Of Us - The Third Mini Album  4vLqN0bIxIQjlet2mIMBnx
# 4          Man On The Moon: The End Of Day  5iSEsR6NKjlC9SrIJkyL3k
#
#    track_popularity  year  artist_popularity  artist_followers  \
# 0                74  2009                 89          14958283
# 1                44  2009                 72            917987
# 2                73  2009                 87           4787381
# 3                59  2009                 73           2289681
# 4                73  2009                 87           4787381
#
#                                               genres  danceability  ...  \
# 0              ['dance pop', 'pop', 'post-teen pop']         0.652  ...
# 1  ['country', 'country rock', 'outlaw country', ...         0.626  ...
# 2                 ['hip hop', 'ohio hip hop', 'rap']         0.871  ...
# 3                       ['k-pop', 'k-pop boy group']         0.835  ...
# 4                 ['hip hop', 'ohio hip hop', 'rap']         0.630  ...
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.0420       0.00112          0.000115    0.0886    0.470   96.021
# 1       0.0384       0.35500          0.000009    0.0668    0.474  102.166
# 2       0.0761       0.49900          0.000004    0.1140    0.799  137.996
# 3       0.0431       0.12500          0.000501    0.2220    0.811  124.980
# 4       0.0414       0.48400          0.000093    0.2980    0.266  115.277
#
#    duration_ms  time_signature  \
# 0       202067               4
# 1       184267               4
# 2       221267               4
# 3       233280               4
# 4       295293               4
#
#                                               lyrics  hit_prediction
# 0  I hopped off the plane at L.A.X. with a dream ...               1
# 1                                                NaN               0
# 2  [Kid Cudi:] Day and night (what, what) I toss ...               1
# 3  [Jonghyun] Baby Negae banhae beorin naegae wae...               1
# 4  Crush a bit, little bit Roll it up, take a hit...               0
#
# [5 rows x 24 columns]

# %%
from IPython.display import display  
from ipywidgets import interact, Text


song = widgets.Combobox(
    placeholder='Choose a Song',
    options=available_songs,
    description='song:',
    ensure_option=True,
    disabled=False)

song
# Out:
# Combobox(value='', description='song:', ensure_option=True, options=('Party In The U.S.A.', 'The Year 2003 Min…

# %%
X_2 = data[['danceability','energy','key','loudness','mode','speechiness','acousticness','instrumentalness','liveness','valence','tempo']]
y_2 = data[['Label']]

X_train, X_test, y_train, y_test = train_test_split(X_2, y_2, test_size=0.2)

model = LogisticRegression()
model.fit(X_train, y_train)

accuracy = model.score(X_test, y_test)



hit_songs = music_data.loc[music_data['hit_prediction'] == 1]

value = song.value in hit_songs['track_name'].values

if value:
    print("Hit")
else:
    print("Not hit")

print(f"accuracy: {accuracy}")    

song.value
# Out:
# Hit
# accuracy: 0.6831275720164609
# 'Fireflies'

# %%
from joblib import dump

# %%
dump(model, './../savedModels/model.joblib')
# Out:
# ['./../savedModels/model.joblib']
